# %%
import pandas as pd
import numpy as np
import glob
import os
from sklearn.preprocessing import OneHotEncoder
from sklearn.utils import class_weight
import pickle
import random

Category = "Country"
countriesOfInterest = ["HK", "JP", 'ZA', 'TN', 'TR', 'GB', 'MX', 'US', 'CO', 'EC', 'AU', 'NZ']

w_length = 200

# %% [markdown]
# ### Consolidate and pickle country files

# %%
for country in countriesOfInterest:
    if len(glob.glob("Raw Track Data\\" + country + ".p")) == 0 :
        hold = pd.DataFrame()
    else:
        hold = pickle.load( open( "Raw Track Data\\" + country + ".p", "rb" ) )
    print(country, hold.shape)
    countryTracks = glob.glob("Raw Track Data\\" + country + "*.csv")
    print(country, len(countryTracks))
    for file in countryTracks[:3]:
        new = pd.read_csv(file)
        new["Country"] = file[15:17]
        new["Year"] = file[18:22]
        new["Playlist"] = file[23:-4]
        hold = hold.append(new)
        pickle.dump( hold, open( "Raw Track Data\\" + country + ".p", "wb" ) )
        os.remove(file)
    hold = hold.drop_duplicates(["track_id", "start"])
    pickle.dump( hold, open( "Raw Track Data\\" + country + ".p", "wb" ) )
# Out:
# HK (294613, 34)
# HK 42
# JP (265941, 34)
# JP 60
# ZA (398666, 34)
# ZA 113
# TN (385718, 34)
# TN 101
# TR (244358, 34)
# TR 76
# GB (279584, 34)
# GB 64
# MX (264737, 34)
# MX 52
# US (395646, 34)
# US 54
# CO (351294, 34)
# CO 103
# EC (376603, 34)
# EC 66
# AU (286392, 34)
# AU 59

# %%
hold
# Out:
#            start  duration  confidence  loudness_start  loudness_max_time  \
# 0        0.00000   0.16848       0.000         -60.000            0.00000
# 1        0.16848   0.31456       1.000         -60.000            0.03755
# 2        0.48304   0.29179       0.920         -31.034            0.03006
# 3        0.77483   0.32286       1.000         -31.801            0.04568
# 4        1.09769   0.33048       1.000         -23.423            0.04884
# ...          ...       ...         ...             ...                ...
# 75109  226.69642   0.74744       0.542         -51.338            0.03968
# 75110  227.44385   0.24535       0.340         -56.262            0.10281
# 75111  227.68921   0.24345       0.504         -55.726            0.03617
# 75112  227.93265   1.03846       0.276         -56.877            0.08522
# 75113  228.97111   3.72222       0.020         -59.304            0.03204
#
#        loudness_max     p1     p2     p3     p4  ...      t7      t8      t9  \
# 0           -60.000  0.919  0.921  0.617  0.694  ...  14.825   5.347 -27.233
# 1           -15.172  0.218  0.196  0.140  0.089  ... -50.742  51.701  21.425
# 2           -19.937  0.076  0.021  0.004  0.008  ... -24.931 -72.536  33.480
# 3           -15.171  0.059  0.014  0.004  0.011  ...  49.786  -8.510  37.845
# 4            -1.113  0.216  0.069  0.031  0.145  ...  -2.500  -6.206  28.074
# ...             ...    ...    ...    ...    ...  ...     ...     ...     ...
# 75109       -46.650  0.579  0.539  0.519  0.476  ... -12.229  10.190 -18.329
# 75110       -53.139  0.616  0.862  0.552  0.346  ...  15.106   1.494 -13.232
# 75111       -51.222  1.000  0.635  0.200  0.255  ...  -8.251  11.590 -21.220
# 75112       -53.562  0.572  0.661  0.731  0.585  ...  21.886  32.606 -12.791
# 75113       -58.349  1.000  0.739  0.968  0.967  ...  15.215  16.016 -25.396
#
#           t10     t11     t12                              track_id  Country  \
# 0       0.969 -10.635  -7.221  spotify:track:28grzRrS5csyaI4uK98IX0       AU
# 1     -29.413  33.257 -24.746  spotify:track:28grzRrS5csyaI4uK98IX0       AU
# 2      14.621 -33.287  10.008  spotify:track:28grzRrS5csyaI4uK98IX0       AU
# 3     -27.952  20.691  10.814  spotify:track:28grzRrS5csyaI4uK98IX0       AU
# 4     -29.403  26.210   9.049  spotify:track:28grzRrS5csyaI4uK98IX0       AU
# ...       ...     ...     ...                                   ...      ...
# 75109  -2.602 -21.835   8.411  spotify:track:3Fzlg5r1IjhLk2qRw667od       AU
# 75110  11.688 -13.572 -20.021  spotify:track:3Fzlg5r1IjhLk2qRw667od       AU
# 75111  -5.335 -13.883  -7.081  spotify:track:3Fzlg5r1IjhLk2qRw667od       AU
# 75112   2.414 -20.031  -5.367  spotify:track:3Fzlg5r1IjhLk2qRw667od       AU
# 75113  -3.048  -5.699  -6.998  spotify:track:3Fzlg5r1IjhLk2qRw667od       AU
#
#        Year                Playlist
# 0      2014  37i9dQZF1DWWmb7Ur0aIYk
# 1      2014  37i9dQZF1DWWmb7Ur0aIYk
# 2      2014  37i9dQZF1DWWmb7Ur0aIYk
# 3      2014  37i9dQZF1DWWmb7Ur0aIYk
# 4      2014  37i9dQZF1DWWmb7Ur0aIYk
# ...     ...                     ...
# 75109  2014  37i9dQZF1DX8ZxAQJCANsW
# 75110  2014  37i9dQZF1DX8ZxAQJCANsW
# 75111  2014  37i9dQZF1DX8ZxAQJCANsW
# 75112  2014  37i9dQZF1DX8ZxAQJCANsW
# 75113  2014  37i9dQZF1DX8ZxAQJCANsW
#
# [439807 rows x 34 columns]

# %% [markdown]
# ### Remove non-unique tracks

# %%
allTracks = pd.DataFrame()
for country in countriesOfInterest:
    hold = pickle.load( open( "Raw Track Data\\" + country + ".p", "rb" ) )
    hold = hold[["Country", "Year", "track_id", "Playlist"]]
    allTracks = allTracks.append(hold)
allTracks
# Out:
#       Country  Year                              track_id  \
# 0          HK  2016  spotify:track:364dI1bYnvamSnBJ8JcNzN
# 1          HK  2016  spotify:track:364dI1bYnvamSnBJ8JcNzN
# 2          HK  2016  spotify:track:364dI1bYnvamSnBJ8JcNzN
# 3          HK  2016  spotify:track:364dI1bYnvamSnBJ8JcNzN
# 4          HK  2016  spotify:track:364dI1bYnvamSnBJ8JcNzN
# ...       ...   ...                                   ...
# 75109      AU  2014  spotify:track:3Fzlg5r1IjhLk2qRw667od
# 75110      AU  2014  spotify:track:3Fzlg5r1IjhLk2qRw667od
# 75111      AU  2014  spotify:track:3Fzlg5r1IjhLk2qRw667od
# 75112      AU  2014  spotify:track:3Fzlg5r1IjhLk2qRw667od
# 75113      AU  2014  spotify:track:3Fzlg5r1IjhLk2qRw667od
#
#                      Playlist
# 0      37i9dQZF1DX4UYQxwfbtyk
# 1      37i9dQZF1DX4UYQxwfbtyk
# 2      37i9dQZF1DX4UYQxwfbtyk
# 3      37i9dQZF1DX4UYQxwfbtyk
# 4      37i9dQZF1DX4UYQxwfbtyk
# ...                       ...
# 75109  37i9dQZF1DX8ZxAQJCANsW
# 75110  37i9dQZF1DX8ZxAQJCANsW
# 75111  37i9dQZF1DX8ZxAQJCANsW
# 75112  37i9dQZF1DX8ZxAQJCANsW
# 75113  37i9dQZF1DX8ZxAQJCANsW
#
# [5281035 rows x 4 columns]

# %%
hold = allTracks.groupby("track_id").nunique()
print(hold.shape[0], "Unique tracks per country")
keep = hold[hold.Country==1].index
allTracks = allTracks[allTracks.track_id.isin(keep)]
print(len(keep), "Unique tracks across countries")
# Out:
# 5448 Unique tracks per country
# 4893 Unique tracks across countries

# %%
for country in countriesOfInterest:
    hold = pickle.load( open( "Raw Track Data\\" + country + ".p", "rb" ) )
    hold = hold[hold.track_id.isin(keep)]
    pickle.dump( hold, open( "Raw Track Data\\" + country + ".p", "wb" ) )

# %% [markdown]
# ### Create training, testing, and validation datasets

# %%
for country in countriesOfInterest:
    hold = pickle.load( open( "Raw Track Data\\" + country + ".p", "rb" ) )
    UniqueTracks = pd.unique(hold.track_id)
    testTracks = np.random.choice(UniqueTracks, int(len(UniqueTracks) * .2), replace = False)
    test = hold.loc[hold.track_id.isin(testTracks)]
    hold = hold.loc[~hold.track_id.isin(testTracks)]
    UniqueTracks = pd.unique(hold.track_id)
    testTracks = np.random.choice(UniqueTracks, int(len(UniqueTracks) * .2), replace = False)
    val = hold.loc[hold.track_id.isin(testTracks)]
    train = hold.loc[~hold.track_id.isin(testTracks)]
    pickle.dump( train, open( "Raw Track Data\\" + country + "_train.p", "wb" ) )
    pickle.dump( test, open( "Raw Track Data\\" + country + "_test.p", "wb" ) )
    pickle.dump( val, open( "Raw Track Data\\" + country + "_val.p", "wb" ) )
