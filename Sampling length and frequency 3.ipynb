# %%
import numpy as np
import os
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
import tensorflow.keras as keras
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.layers import LSTM, Dense, Flatten, BatchNormalization, Dropout, GRU
from tensorflow.keras.utils import to_categorical
import tensorflow as tf
import module
import gc
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
countriesOfInterest = {"HK", "JP", 'ZA', 'TN', 'TR', 'GB', 'MX', 'US', 'CO', 'EC', 'AU', 'NZ'}
countriesOfInterest = ["ZA", "EG", "TW", "JP", "DK", "FI", "US", "CA", "AU", "NZ", "BR", "CO"]

enc = OneHotEncoder()
enc.fit(np.array(countriesOfInterest).reshape(-1, 1))
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=True)

# %% [markdown]
# ### Test Sampling

# %%
train_n = 100
sample_n = train_n * 20
val_n  = int(train_n/5)
valsample_n = val_n * 20
for seconds in [1, 3, 5, 10]:
    for samplerate in [1]:
        train_x, train_labels, val_x, val_labels, class_weights = module.getSamples(10, 1, 10, 1, 
                                                                                    seconds, 
                                                                                    samplerate, 
                                                                                    countriesOfInterest, 
                                                                                    enc, 
                                                                                    verbose = 0)
        print(train_x.shape)
        model = keras.Sequential()
        model.add(BatchNormalization(input_shape=(train_x.shape[1], train_x.shape[2])))

        model.add(LSTM(16, 
                       input_shape=(train_x.shape[1], train_x.shape[2]), 
                       return_sequences = True
                      ))
        model.add(BatchNormalization())
        model.add(LSTM(32, 
                       return_sequences = False,
                       go_backwards = True
                      ))
        model.add(BatchNormalization())
        model.add(Dense(16, activation= "relu"))
        model.add(BatchNormalization())
        model.add(Dense(len(enc.categories_[0]), activation= "softmax"))
        adam = keras.optimizers.Adam(lr=0.001, amsgrad = True)
        model.compile(loss = "categorical_crossentropy", optimizer= adam, metrics=["acc"])
        del train_x, train_labels, val_x, val_labels, class_weights
        gc.collect()
        print(model.summary())
        desc = str(seconds) + "_seconds_" + str(samplerate) + "_samples"
        log_dir = os.path.join(
            "logs",
            "Quality",
            desc
        )
        model_dir = os.path.join(
            "pickle",
            desc
        )


        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
        epochs = 2
        iterations = 50
        learn_rate = 0.001
        batch_size = 4096
        model = module.train(iterations, learn_rate, train_n, sample_n, val_n, valsample_n, seconds, samplerate,
                        countriesOfInterest, enc, epochs, tensorboard_callback, model_dir,
                        model, batch_size)
        del model, model_dir, log_dir, desc, adam
        gc.collect()
# Out:
# (12, 1, 25)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 1, 25)             100
# _________________________________________________________________
# lstm (LSTM)                  (None, 1, 16)             2688
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1, 16)             64
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 32)                6272
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16)                64
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                204
# =================================================================
# Total params: 10,048
# Trainable params: 9,870
# Non-trainable params: 178
# _________________________________________________________________
# None
# 1_seconds_1_samples iteration 5
# 4800/4800 [==============================] - 0s 99us/sample
# 24000/24000 [==============================] - 0s 1us/sample
# 1_seconds_1_samples iteration 10
# 4800/4800 [==============================] - 0s 99us/sample
# 24000/24000 [==============================] - 0s 1us/sample
# 1_seconds_1_samples iteration 15
# 4800/4800 [==============================] - 0s 97us/sample
# 24000/24000 [==============================] - 0s 2us/sample
# 1_seconds_1_samples iteration 20
# 4800/4800 [==============================] - 0s 92us/sample
# 24000/24000 [==============================] - 0s 1us/sample
# 1_seconds_1_samples iteration 25
# 4800/4800 [==============================] - 0s 88us/sample
# 24000/24000 [==============================] - 0s 1us/sample
# 1_seconds_1_samples iteration 30
# 4800/4800 [==============================] - 1s 230us/sample
# 24000/24000 [==============================] - 0s 3us/sample
# 1_seconds_1_samples iteration 35
# 4800/4800 [==============================] - 0s 89us/sample
# 24000/24000 [==============================] - 0s 2us/sample
# 1_seconds_1_samples iteration 40
# 4800/4800 [==============================] - 0s 81us/sample
# 24000/24000 [==============================] - 0s 1us/sample
# 1_seconds_1_samples iteration 45
# 4800/4800 [==============================] - 0s 82us/sample
# 24000/24000 [==============================] - 0s 1us/sample
# 1_seconds_1_samples iteration 50
# 4800/4800 [==============================] - 0s 75us/sample
# 24000/24000 [==============================] - 0s 2us/sample
# (12, 3, 25)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_4 (Batch (None, 3, 25)             100
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 3, 16)             2688
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 16)             64
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 32)                6272
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32)                128
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16)                64
# _________________________________________________________________
# dense_3 (Dense)              (None, 12)                204
# =================================================================
# Total params: 10,048
# Trainable params: 9,870
# Non-trainable params: 178
# _________________________________________________________________
# None
# 3_seconds_1_samples iteration 5
# 4800/4800 [==============================] - 0s 75us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 10
# 4800/4800 [==============================] - 0s 75us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 15
# 4800/4800 [==============================] - 0s 75us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 20
# 4800/4800 [==============================] - 0s 79us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 25
# 4800/4800 [==============================] - 0s 77us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 30
# 4800/4800 [==============================] - 0s 76us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 35
# 4800/4800 [==============================] - 0s 75us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 40
# 4800/4800 [==============================] - 0s 74us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 45
# 4800/4800 [==============================] - 0s 79us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# 3_seconds_1_samples iteration 50
# 4800/4800 [==============================] - 0s 74us/sample
# 24000/24000 [==============================] - 0s 4us/sample
# (12, 5, 25)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_8 (Batch (None, 5, 25)             100
# _________________________________________________________________
# lstm_4 (LSTM)                (None, 5, 16)             2688
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 16)             64
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 32)                6272
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 32)                128
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16)                64
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                204
# =================================================================
# Total params: 10,048
# Trainable params: 9,870
# Non-trainable params: 178
# _________________________________________________________________
# None
# 5_seconds_1_samples iteration 5
# 4800/4800 [==============================] - 0s 81us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 10
# 4800/4800 [==============================] - 0s 77us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 15
# 4800/4800 [==============================] - 0s 76us/sample
# 24000/24000 [==============================] - 0s 7us/sample
# 5_seconds_1_samples iteration 20
# 4800/4800 [==============================] - 0s 76us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 25
# 4800/4800 [==============================] - 0s 76us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 30
# 4800/4800 [==============================] - 0s 78us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 35
# 4800/4800 [==============================] - 0s 81us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 40
# 4800/4800 [==============================] - 0s 78us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 45
# 4800/4800 [==============================] - 0s 78us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# 5_seconds_1_samples iteration 50
# 4800/4800 [==============================] - 0s 77us/sample
# 24000/24000 [==============================] - 0s 6us/sample
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-83377fa55804> in <module>
#      10                                                                                     countriesOfInterest,
#      11                                                                                     enc,
# ---> 12                                                                                     verbose = 0)
#      13         print(train_x.shape)
#      14         model = keras.Sequential()
#
# ~\OneDrive - Emory University\Course Work\Spring 2020\CS 584 - Deep Learning\Class Project\module.py in getSamples(train_n, sample_n, val_n, valsample_n, seconds, samplerate, countriesOfInterest, enc, verbose)
#      64         if verbose > 0:
#      65             print("getting",country)
# ---> 66         x1, y1 = splitSeconds(train_n, sample_n, country, "train", seconds, samplerate)
#      67         x2, y2 = splitSeconds(val_n, valsample_n, country, "val", seconds, samplerate)
#      68         if train_x is None:
#
# ~\OneDrive - Emory University\Course Work\Spring 2020\CS 584 - Deep Learning\Class Project\module.py in splitSeconds(n, sample_n, country, t, seconds, samplerate)
#      40         if i.shape[0] == length:
#      41             samples = samples + [i]
# ---> 42     samples = np.stack(samples)
#      43     if sample_n is not None:
#      44         if sample_n <= len(samples):
#
# <__array_function__ internals> in stack(*args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\shape_base.py in stack(arrays, axis, out)
#     419     arrays = [asanyarray(arr) for arr in arrays]
#     420     if not arrays:
# --> 421         raise ValueError('need at least one array to stack')
#     422
#     423     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack

# %%
train_n = 100
sample_n = train_n * 20
val_n  = int(train_n/5)
valsample_n = val_n * 20
for seconds in [10]:
    for samplerate in [1]:
        train_x, train_labels, val_x, val_labels, class_weights = module.getSamples(100, 10, 100, 10, 
                                                                                    seconds, 
                                                                                    samplerate, 
                                                                                    countriesOfInterest, 
                                                                                    enc, 
                                                                                    verbose = 0)
        print(train_x.shape)
        model = keras.Sequential()
        model.add(BatchNormalization(input_shape=(train_x.shape[1], train_x.shape[2])))

        model.add(LSTM(16, 
                       input_shape=(train_x.shape[1], train_x.shape[2]), 
                       return_sequences = True
                      ))
        model.add(BatchNormalization())
        model.add(LSTM(32, 
                       return_sequences = False,
                       go_backwards = True
                      ))
        model.add(BatchNormalization())
        model.add(Dense(16, activation= "relu"))
        model.add(BatchNormalization())
        model.add(Dense(len(enc.categories_[0]), activation= "softmax"))
        adam = keras.optimizers.Adam(lr=0.001, amsgrad = True)
        model.compile(loss = "categorical_crossentropy", optimizer= adam, metrics=["acc"])
        del train_x, train_labels, val_x, val_labels, class_weights
        gc.collect()
        print(model.summary())
        desc = str(seconds) + "_seconds_" + str(samplerate) + "_samples"
        log_dir = os.path.join(
            "logs",
            "Quality",
            desc
        )
        model_dir = os.path.join(
            "pickle",
            desc
        )


        tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
        epochs = 2
        iterations = 50
        learn_rate = 0.001
        batch_size = 4096
        model = module.train(iterations, learn_rate, train_n, sample_n, val_n, valsample_n, seconds, samplerate,
                        countriesOfInterest, enc, epochs, tensorboard_callback, model_dir,
                        model, batch_size)
        del model, model_dir, log_dir, desc, adam
        gc.collect()
# Out:
# (120, 10, 25)
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_12 (Batc (None, 10, 25)            100
# _________________________________________________________________
# lstm_6 (LSTM)                (None, 10, 16)            2688
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 10, 16)            64
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 32)                6272
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32)                128
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 16)                64
# _________________________________________________________________
# dense_7 (Dense)              (None, 12)                204
# =================================================================
# Total params: 10,048
# Trainable params: 9,870
# Non-trainable params: 178
# _________________________________________________________________
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3e5eec202617> in <module>
#      52         model = module.train(iterations, learn_rate, train_n, sample_n, val_n, valsample_n, seconds, samplerate,
#      53                         countriesOfInterest, enc, epochs, tensorboard_callback, model_dir,
# ---> 54                         model, batch_size)
#      55         del model, model_dir, log_dir, desc, adam
#      56         gc.collect()
#
# ~\OneDrive - Emory University\Course Work\Spring 2020\CS 584 - Deep Learning\Class Project\module.py in train(iterations, learn_rate, train_n, sample_n, val_n, valsample_n, seconds, samplerate, countriesOfInterest, enc, epochs, tensorboard_callback, model_dir, model, b_size)
#     108         adam = keras.optimizers.Adam(lr=learn_rate, amsgrad = True)
#     109         model.compile(loss = "categorical_crossentropy", optimizer= adam, metrics=["acc"])
# --> 110         train_x, train_labels, val_x, val_labels, class_weights = getSamples(train_n, sample_n, val_n, valsample_n, seconds, samplerate, countriesOfInterest, enc)
#     111         #print("train", np.sum(train_labels, axis = 0))
#     112         #print("val", np.sum(val_labels, axis = 0))
#
# ~\OneDrive - Emory University\Course Work\Spring 2020\CS 584 - Deep Learning\Class Project\module.py in getSamples(train_n, sample_n, val_n, valsample_n, seconds, samplerate, countriesOfInterest, enc, verbose)
#      65             print("getting",country)
#      66         x1, y1 = splitSeconds(train_n, sample_n, country, "train", seconds, samplerate)
# ---> 67         x2, y2 = splitSeconds(val_n, valsample_n, country, "val", seconds, samplerate)
#      68         if train_x is None:
#      69             train_x = x1
#
# ~\OneDrive - Emory University\Course Work\Spring 2020\CS 584 - Deep Learning\Class Project\module.py in splitSeconds(n, sample_n, country, t, seconds, samplerate)
#      40         if i.shape[0] == length:
#      41             samples = samples + [i]
# ---> 42     samples = np.stack(samples)
#      43     if sample_n is not None:
#      44         if sample_n <= len(samples):
#
# <__array_function__ internals> in stack(*args, **kwargs)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\shape_base.py in stack(arrays, axis, out)
#     419     arrays = [asanyarray(arr) for arr in arrays]
#     420     if not arrays:
# --> 421         raise ValueError('need at least one array to stack')
#     422
#     423     shapes = {arr.shape for arr in arrays}
#
# ValueError: need at least one array to stack
